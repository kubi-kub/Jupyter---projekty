# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

def getImage(paths):
    return OffsetImage(plt.imread(path))

plt.style.use('dark_background')
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot()

ax.set_xlim(0.1,250)
ax.set_xscale('log')
ax.set_ylim(0.22,40)
ax.set_yscale('log')
ax.set_title('Wizualizacja trzeciego prawa Keplera')
ax.set_xlabel('Okres orbitalny w latach (log)')
ax.set_ylabel('Półoś wielka w AU (log)')

ax.text(0.3,10, r"$\frac{T^2}{r^3} = const$", size = 16)

x = np.linspace(0.1,250,10000)
y = (x**2)**(1/3)
ax.plot(x,y)

paths = [
    'mercury.png',
    'wenus.png',
    'earth.png',
    'mars.png',
    'jupiter.png',
    'saturn.png',
    'uranus.png',
    'neptune.png']
xx = [0.2408467, 0.61519726, 1.0000174, 1.8808158, 11.862615, 29.447498, 84.016846, 164.79132]
yy = [0.3870993, 0.723336, 1.000003, 1.52371, 5.2029, 9.537, 19.189, 30.0699]
for x0, y0, path in zip(xx, yy, paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)

plt.savefig('03_lew_275116.pdf',dpi=300)
plt.show()
